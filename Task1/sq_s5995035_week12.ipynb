# %% [markdown]
# **1.2**
# Answers for week 1
#
# * Name: Anna Stroeve
# * Username: agstroeve
# * Student s-number: S5995035
# * Group: AS2

# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=6
x*=5
x*=4
x*=3
x*=2
x*=1
print(x)
# Out:
# 720

# %% [markdown]
# **1.5**

# %%
mass_moon = 7.342e22
mass_earth = 5.9722e24
from scipy.constants import G
r = 385000000.6
F=(G*mass_moon*mass_earth)/(r**2)
print(F)
# Out:
# 1.9743901995827397e+20

# %% [markdown]
# **1.10**
# ![Screenshot 2026-02-13 144052.png](attachment:792b0309-907f-4b9c-a8c0-90cb8df2fb26.png)

# %% [markdown]
# **1.11**
# ![Screenshot 2026-02-11 180428.png](attachment:6cf93bc1-55f1-4c47-be0a-334182a05595.png)

# %% [markdown]
# **1.12**
# ![Screenshot 2026-02-13 145638.png](attachment:354c10e9-d2d6-4c43-8733-7538d68ee0b7.png)

# %% [markdown]
# **1.13**
# ![Screenshot 2026-02-13 153503.png](attachment:25641f80-1dfc-44bc-9158-024d4a643035.png)

# %% [markdown]
# **1.15**
# 1. /Users/users/agstroeve/Downloads
# 2. The notation . refers to the current directory
#    The notation .. refers to the parent directory (one up)

# %% [markdown]
# **1.16**
# cd ~/Desktop

# %% [markdown]
# **1.19**
# 1. ls *[0-9]*.[co] shows all files beginning with anything followed by a number 0-9, then anything followed by either c or o.
# 2. The square brackets mean either one of the things mentioned in between the brackets. In this case [co] means c or o. The - means from .. until .. .
# 3. The command ls *[0-9]*.co is different because the co means 'co' only. No o, c, or oc.
